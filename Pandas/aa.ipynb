# %%
import pandas as pd
mydataset = {
  'cars': ["Volvo", "BMW", "Ford"],
  'passings': [3, 7, 2]
}
df = pd.DataFrame(mydataset)
print(df.sort_values(by="passings"))
# Out:
#     cars  passings
# 2   Ford         2
# 0  Volvo         3
# 1    BMW         7

# %%
import pandas as pd
mydataset = {
  'cars': ["Volvo", "BMW", "Ford"],
  'passings': [3, 7, 2]
}
df = pd.DataFrame(mydataset)
df.loc["1":"2", ["cars", "passings"]]
# Out:
#    cars  passings
# 1   BMW         7
# 2  Ford         2

# %%
import pandas as pd
mydataset = {
  'cars': ["Volvo", "BMW", "Ford"],
  'passings': [3, 7, 2]
}
df = pd.DataFrame(mydataset)
df2 =df.copy()
df2[df2["cars"].isin(["Volvo"])]
# Out:
#     cars  passings
# 0  Volvo         3

# %%
import pandas as pd
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
import pandas as pd
mydataset = {
  'cars': ["Volvo", "BMW", "Ford"],
  'passings': [3, 7, 2]
}
df = pd.DataFrame(mydataset)
df2 =df.copy()
print(df2.loc[1])
# Out:
# cars        BMW
# passings      7
# Name: 1, dtype: object

# %%
import pandas as pd
obj = {'col1': ['leonardo','carlos' ], 'col2': [1234, 4321]}
df = pd.DataFrame(data=obj)
df
# Out:
#        col1  col2
# 0  leonardo  1234
# 1    carlos  4321

# %%
import pandas as pd 
file_path = "C:/Users/leona/Documentos/PROJETO/Estudos_com_Pandas/arrecadacao-cnae.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1",on_bad_lines="skip",sep=';')
df['IRPF'] = df['IRPF'].str.replace('.', '', regex=False)  # Remove o ponto
df['IRPF'] = df['IRPF'].str.replace(',', '.', regex=False) 
df["IRPF"]=pd.to_numeric(df["IRPF"])
mais_de_mil=df[df['IRPF']<1000]
df
# Out:
#        Ano  Mês Seção - Sigla  \
# 0     2016  Jan             A
# 1     2016  Jan             B
# 2     2016  Jan             C
# 3     2016  Jan             D
# 4     2016  Jan             E
# ...    ...  ...           ...
# 2515  2024  Set             Q
# 2516  2024  Set             R
# 2517  2024  Set             S
# 2518  2024  Set             T
# 2519  2024  Set             U
#
#                                            Seção - Nome                II  \
# 0     Agricultura, pecuária, prod. florestal, pesca ...      2.742.218,39
# 1                                 Indústrias extrativas     42.899.799,99
# 2                           Indústrias de transformação  1.633.818.001,81
# 3                                    Eletricidade e gás      5.328.420,02
# 4     Água, esgoto, ativ. de gestão de resíduos e de...        354.256,59
# ...                                                 ...               ...
# 2515                    Saúde humana e serviços sociais         954976,24
# ...

# %%
data1 = {'Nome': ['Ana', 'João'], 'Idade': [22, 34]}
data2 = {'Nome': ['João', 'Ana'], 'Cidade': ['São Paulo', 'Curitiba']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
merged = pd.merge(df1, df2, on='Nome')
print(merged)
# Out:
#    Nome  Idade     Cidade
# 0   Ana     22   Curitiba
# 1  João     34  São Paulo

# %%
import pandas as pd 
file_path = "C:/Users/leona/Documentos/PROJETO/Estudos_com_Pandas/arrecadacao-cnae.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1",on_bad_lines="skip",sep=';')
df['IRPF'] = df['IRPF'].str.replace('.', '', regex=False)  # Remove o ponto
df['IRPF'] = df['IRPF'].str.replace(',', '.', regex=False) 
df['IRPF'].fillna(0, inplace=True)

df['IRPF'] = df['IRPF'].astype(float)

df
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_15048\796514646.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IRPF'].fillna(0, inplace=True)
#        Ano  Mês Seção - Sigla  \
# 0     2016  Jan             A
# 1     2016  Jan             B
# 2     2016  Jan             C
# 3     2016  Jan             D
# 4     2016  Jan             E
# ...    ...  ...           ...
# 2515  2024  Set             Q
# 2516  2024  Set             R
# 2517  2024  Set             S
# 2518  2024  Set             T
# ...

# %%
import pandas as pd 
file_path = "C:/Users/leona/Documentos/PROJETO/Estudos_com_Pandas/arrecadacao-cnae.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1",on_bad_lines="skip",sep=';')
df['IRPF'] = df['IRPF'].str.replace('.', '', regex=False)  # Remove o ponto
df['IRPF'] = df['IRPF'].str.replace(',', '.', regex=False)

# %%
import pandas as pd

# Dados de Vendas de Produtos
dados_vendas = {
    'Produto': ['Celular', 'Notebook', 'Tablet', 'Celular', 'Notebook', 'Tablet'],
    'Quantidade': [15, 5, 8, 10, 3, 6],
    'Preço': [1500.00, 3500.00, 1200.00, 1450.00, 3400.00, 1250.00],
    'Data_Venda': ['2024-01-12', '2024-02-05', '2024-03-18', '2024-04-22', '2024-05-15', '2024-06-30']
}
# Cria o DataFrame
df = pd.DataFrame(dados_vendas)
df['Total vendido'] = df['Preço']*df["Quantidade"]
df['Total vendido'].astype(float)
df
# Out:
#     Produto  Quantidade   Preço  Data_Venda  Total vendido
# 0   Celular          15  1500.0  2024-01-12        22500.0
# 1  Notebook           5  3500.0  2024-02-05        17500.0
# 2    Tablet           8  1200.0  2024-03-18         9600.0
# 3   Celular          10  1450.0  2024-04-22        14500.0
# 4  Notebook           3  3400.0  2024-05-15        10200.0
# 5    Tablet           6  1250.0  2024-06-30         7500.0
